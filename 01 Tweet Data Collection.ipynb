# %%
import pandas as pd
import GetOldTweets3 as got
from time import sleep

# %%
def get_tweets(username, top_only, start_date, end_date, max_tweets):

    tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                    .setTopTweets(top_only)\
                    .setSince(start_date)\
                    .setUntil(end_date)\
                    .setMaxTweets(max_tweets)

    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    print(f"Total tweets scraped: {len(tweets)}")

    text_tweets = [[tw.username,
                tw.text,
                tw.date,
                tw.retweets,
                tw.favorites,
                tw.mentions,
                tw.hashtags] for tw in tweets]
    
    news_df = pd.DataFrame(text_tweets, 
                            columns = ['User', 'Text', 'Date', 'Favorites', 'Retweets', 'Mentions', 'HashTags'])
    
    return news_df

# %%
news_sources = ['La_DOTD','TxDot','BR_Traffic', 'NOLA_Traffic','Laf_Traffic', 'NS_Traffic', 
                'LC_Traffic', 'wbrztraffic', 'WAFBTraffic', 'LAStatePolice', 'BTRtraffic']

news_df = get_tweets(news_sources, 
                     top_only = False,
                     start_date = "2020-08-07", 
                     end_date = "2020-09-04",
                     max_tweets = 2000).sort_values('Date', ascending=False)
news_df.head()
# Out:
# Total tweets scraped: 1931
#          User                                               Text  \
# 0  BTRtraffic  RT BR_Traffic The center lane is blocked on I-...
# 1  BR_Traffic  The center lane is blocked on I-10 West at Ess...
# 2  BTRtraffic  RT BR_Traffic Congestion remains on I-12 East ...
# 3  NS_Traffic  Congestion remains on I-12 East from Mile Mark...
# 4  BR_Traffic  Congestion remains on I-12 East from Mile Mark...
#
#                        Date  Favorites  Retweets Mentions HashTags
# 0 2020-09-03 23:56:21+00:00          0         0
# 1 2020-09-03 23:50:57+00:00          1         0
# 2 2020-09-03 23:30:46+00:00          0         0
# 3 2020-09-03 23:30:37+00:00          0         0
# 4 2020-09-03 23:30:32+00:00          1         0

# %%
news_df.shape
# Out:
# (1931, 7)

# %%
news_df.head(50)
# Out:
#             User                                               Text  \
# 0     BTRtraffic  RT BR_Traffic The center lane is blocked on I-...
# 1     BR_Traffic  The center lane is blocked on I-10 West at Ess...
# 2     BTRtraffic  RT BR_Traffic Congestion remains on I-12 East ...
# 3     NS_Traffic  Congestion remains on I-12 East from Mile Mark...
# 4     BR_Traffic  Congestion remains on I-12 East from Mile Mark...
# 5     BTRtraffic  RT BR_Traffic All lanes are now open on I-10 W...
# 6     BR_Traffic  All lanes are now open on I-10 West on the Mis...
# 7     BTRtraffic  RT BR_Traffic The center lane is blocked on I-...
# 8     BR_Traffic  The center lane is blocked on I-10 West at Per...
# 9     BTRtraffic  RT BR_Traffic There is congestion on I-12 East...
# 10    BR_Traffic  There is congestion on I-12 East from Mile Mar...
# 11    NS_Traffic  There is congestion on I-12 East from Mile Mar...
# 12    BTRtraffic  RT BR_Traffic The center lane is now open and ...
# 13    BR_Traffic  The center lane is now open and the right lane...
# 8  2020-09-03 23:07:12+00:00          0         0
# 9  2020-09-03 22:41:13+00:00          0         0
# 10 2020-09-03 22:37:33+00:00          1         0
# 11 2020-09-03 22:37:28+00:00          0         0
# 12 2020-09-03 22:21:08+00:00          0         0
# 13 2020-09-03 22:18:45+00:00          0         0
# 14 2020-09-03 22:18:02+00:00          0         1
# 15 2020-09-03 22:14:44+00:00          0         0
# 16 2020-09-03 22:09:20+00:00          0         0
# 17 2020-09-03 22:04:04+00:00          0         0
# 18 2020-09-03 21:52:37+00:00          0         0
# 19 2020-09-03 21:40:48+00:00          0         0
# 20 2020-09-03 21:40:47+00:00          0         0
# 21 2020-09-03 21:38:17+00:00          1         0
# 22 2020-09-03 21:37:11+00:00          0         0
# 23 2020-09-03 21:37:04+00:00          1         0
# 24 2020-09-03 21:01:15+00:00          0         0
# 25 2020-09-03 20:58:49+00:00          0         0
# 26 2020-09-03 20:58:43+00:00          1         0
# 27 2020-09-03 20:36:09+00:00          0         8
# 28 2020-09-03 20:35:12+00:00          0         5
# 29 2020-09-03 20:28:25+00:00          0         0
# 30 2020-09-03 20:26:31+00:00          1         0
# 31 2020-09-03 20:26:26+00:00          0         0
# 32 2020-09-03 20:18:35+00:00          4        22
# 33 2020-09-03 20:13:43+00:00          0         0
# 34 2020-09-03 20:10:32+00:00          0         0
# 35 2020-09-03 20:10:28+00:00          0         0
# 36 2020-09-03 20:10:23+00:00          0         0
# 37 2020-09-03 19:52:41+00:00          1         1
# 38 2020-09-03 18:23:59+00:00          4         5
# 39 2020-09-03 18:14:45+00:00          0         0
# 40 2020-09-03 17:32:26+00:00          0         0
# 41 2020-09-03 17:27:59+00:00          0         0
# 42 2020-09-03 15:49:44+00:00          0         0
# 43 2020-09-03 15:27:51+00:00          0         0
# 44 2020-09-03 15:24:46+00:00          3         0
# 45 2020-09-03 15:13:04+00:00          0         0
# 46 2020-09-03 15:12:51+00:00          2         0
# 47 2020-09-03 15:04:26+00:00          0         0           #BTRtraffic
# 48 2020-09-03 15:03:25+00:00          0         0
# 49 2020-09-03 15:02:44+00:00          2         0

# %%
news_df.to_csv('tweets_data/news_df.csv', index = False)

# %%
def get_tweets2(keyword_list, top_only, city, start_date, end_date, max_tweets):
    
    df = pd.DataFrame()
    
    for i in keyword_list:

        tweetCriteria = got.manager.TweetCriteria().setQuerySearch(i)\
                    .setTopTweets(top_only)\
                    .setNear(city)\
                    .setWithin("200mi")\
                    .setSince(start_date)\
                    .setUntil(end_date)\
                    .setMaxTweets(max_tweets)

        tweets = got.manager.TweetManager.getTweets(tweetCriteria)

        text_tweets = [[tw.username,
                tw.text,
                tw.date,
                tw.retweets,
                tw.favorites,
                tw.mentions,
                tw.hashtags] for tw in tweets]
    
        df2 = pd.DataFrame(text_tweets, 
                            columns = ['User', 'Text', 'Date', 'Favorites', 'Retweets', 'Mentions', 'HashTags'])
        
        df = df.append(df2)
        
        print(f"Total tweets scraped: {len(df)}")
        
        sleep(300)
        
    return df

# %%
keywords1 = ['hurricane', 'closed', 'close']
keywords2 = ['congestion', 'blocked', 'highway', 
            'traffic']
keywords3 = ['route', 'open', 'lane', 'road']
keywords4 = ['shut down', 'detour', 'evacuation', 'hwy']

news4_df = get_tweets2(keyword_list = keywords4,
                     top_only = False,
                     city = "Lake Charles, Louisiana",
                     start_date = "2020-08-24", 
                     end_date = "2020-09-01",
                     max_tweets = 10_000).sort_values('Date', ascending=False)
    
news4_df.head()
# Out:
# Total tweets scraped: 146
# Total tweets scraped: 150
# Total tweets scraped: 453
# Total tweets scraped: 621
#              User                                               Text  \
# 1    LenovoLegion  Lenovo Legion x @PlayApex Now is your chance t...
# 140  LenovoLegion  Lenovo Legion x @PlayApex Now is your chance t...
# 22   LenovoLegion  Lenovo Legion x @PlayApex Now is your chance t...
# 43   LenovoLegion  Lenovo Legion x @PlayApex Now is your chance t...
# 85   LenovoLegion  Lenovo Legion x @PlayApex Now is your chance t...
#
#                          Date  Favorites  Retweets   Mentions HashTags
# 1   2020-09-03 18:26:48+00:00          9       106  @PlayApex
# 140 2020-09-03 18:26:48+00:00          9       106  @PlayApex
# 22  2020-09-03 18:26:48+00:00          9       106  @PlayApex
# 43  2020-09-03 18:26:48+00:00          9       106  @PlayApex
# 85  2020-09-03 18:26:48+00:00          9       106  @PlayApex

# %%
news4_df.shape
# Out:
# (621, 7)

# %%
news4_df.tail()
# Out:
#                 User                                               Text  \
# 143      KirstenMaya  We riding down highland, and LSU might as well...
# 144   Willie_Beamerr  Peaceful Protesters shut down Ambassador today..
# 301        Shawdaaaa  I’m not 100% if we have to evacuate but I’m su...
# 302        Shawdaaaa  This what I’m seeing. If it’s a mandatory evac...
# 145  OneDamnLuckyGuy  Not even 2 minutes into the interview @DavidMu...
#
#                          Date  Favorites  Retweets  \
# 143 2020-08-24 01:58:15+00:00          2         7
# 144 2020-08-24 01:06:58+00:00          0         1
# 301 2020-08-24 01:06:51+00:00          0         0
# 302 2020-08-24 00:47:47+00:00          0         0
# 145 2020-08-24 00:13:16+00:00          0         0
#
#                            Mentions HashTags
# 143
# 144
# 301
# 302
# 145  @DavidMuir @POTUS @ABCPolitics

# %%
news4_df.to_csv('tweets_data/news4_df.csv', index = False)

# %%
csv_list = ["news_df.csv", "news1_df.csv", "news2_df.csv", "news3_df.csv", "news4_df.csv"]

df_list = []
for i in csv_list:
    df_list.append(pd.read_csv('tweets_data/' + i))

lake_ch_tweets_2 = pd.concat(df_list)

lake_ch_tweets_2.shape
# Out:
# (12680, 7)

# %%
lake_ch_tweets_2.to_csv('tweets_data/lake_ch_tweets_2.csv', index = False)
